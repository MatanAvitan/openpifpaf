# %% [markdown]
# <h1>Table of Contents<span class="tocSkip"></span></h1>
# <div class="toc"><ul class="toc-item"><li><ul class="toc-item"><li><span><a href="#Load-train-annotations" data-toc-modified-id="Load-train-annotations-0.1"><span class="toc-item-num">0.1&nbsp;&nbsp;</span>Load train annotations</a></span></li><li><span><a href="#Load-val-annotations" data-toc-modified-id="Load-val-annotations-0.2"><span class="toc-item-num">0.2&nbsp;&nbsp;</span>Load val annotations</a></span></li></ul></li><li><span><a href="#explore-val-annotations" data-toc-modified-id="explore-val-annotations-1"><span class="toc-item-num">1&nbsp;&nbsp;</span>explore val annotations</a></span><ul class="toc-item"><li><span><a href="#explore-train-annotations" data-toc-modified-id="explore-train-annotations-1.1"><span class="toc-item-num">1.1&nbsp;&nbsp;</span>explore train annotations</a></span></li></ul></li></ul></div>

# %%
import json

# %%
! ls
# Out:
# CLAC.txt                         datasets
# CLAI.txt                         docs
# CONTRIBUTING.md                  models
# HISTORY.md                       openpifpaf
# LICENSE                          scripts
# LICENSE.AGPL                     setup.cfg
# MANIFEST.in                      setup.py
# README.md                        temp_docker_dir
# create_new_annotation_file.ipynb tests

# %%
! ls openpifpaf/
# Out:
# -6dae05c8.our_model             our_model.epoch001
# __init__.py                     our_model.epoch002
# __pycache__                     our_model.log
# benchmark.py                    output_eval_coco.txt.pred.json
# coco_stats.py                   output_eval_coco.txt.stats.json
# consts.py                       output_eval_coco.txt.txt
# count_ops.py                    output_eval_coco.txt.zip
# data.py                         outputs
# datasets.py                     predict.py
# decoder                         show.py
# encoder                         student_model_1.pred.json
# eval_coco.py                    student_model_1.stats.json
# export_onnx.py                  student_model_1.txt
# functional.c                    student_model_1.zip
# functional.pyx                  train.py
# logs.py                         train_instance_scorer.py
# migrate.py                      transforms
# model_output.log                utils.py
# network                         webcam.py
# ...

# %%
with open('openpifpaf/student_model_1.pred.json') as f:
    students_preds = json.load(f)

# %%
students_preds
# Out:
# [{'image_id': 516038,
#   'category_id': 1,
#   'keypoints': [247.0399932861328,
#    122.66999816894531,
#    2.0,
#    249.75,
#    119.08000183105469,
#    2.0,
#    243.5,
#    119.79000091552734,
#    2.0,
#    253.64999389648438,
#    118.6500015258789,
#    2.0,
#    238.02000427246094,
#    120.08000183105469,
#    2.0,
#    263.1400146484375,
#    130.6300048828125,
#    2.0,
#    229.74000549316406,
#    130.3000030517578,
#    2.0,
#    277.6099853515625,
#    149.92999267578125,
#    2.0,
#    216.38999938964844,
#    148.89999389648438,
#    2.0,
#    272.2099914550781,
#    169.6199951171875,
#    2.0,
#    221.63999938964844,
#    168.7100067138672,
#    2.0,
#    257.29998779296875,
#    154.17999267578125,
#    2.0,
#    235.16000366210938,
#    154.10000610351562,
#    2.0,
#    275.1199951171875,
#    179.64999389648438,
#    2.0,
#    220.82000732421875,
#    178.58999633789062,
#    2.0,
#    286.9599914550781,
#    212.99000549316406,
#    2.0,
# ...

# %% [markdown]
# #### Load train annotations

# %%
train_annotations_path = 'datasets/data-mscoco/annotations/person_keypoints_train2017.json'

# %%
with open(train_annotations_path) as f:
    train_annotations = json.load(f)

# %% [markdown]
# #### Load val annotations

# %%
val_annotations_path = 'datasets/data-mscoco/annotations/person_keypoints_val2017.json'

# %%
with open(val_annotations_path) as f:
    val_annotations = json.load(f)

# %% [markdown]
# ### explore val annotations

# %%
val_annotations.keys()
# Out:
# dict_keys(['info', 'licenses', 'images', 'annotations', 'categories'])

# %%
val_annotations['info']
# Out:
# {'description': 'COCO 2017 Dataset',
#  'url': 'http://cocodataset.org',
#  'version': '1.0',
#  'year': 2017,
#  'contributor': 'COCO Consortium',
#  'date_created': '2017/09/01'}

# %%
val_annotations['licenses']
# Out:
# [{'url': 'http://creativecommons.org/licenses/by-nc-sa/2.0/',
#   'id': 1,
#   'name': 'Attribution-NonCommercial-ShareAlike License'},
#  {'url': 'http://creativecommons.org/licenses/by-nc/2.0/',
#   'id': 2,
#   'name': 'Attribution-NonCommercial License'},
#  {'url': 'http://creativecommons.org/licenses/by-nc-nd/2.0/',
#   'id': 3,
#   'name': 'Attribution-NonCommercial-NoDerivs License'},
#  {'url': 'http://creativecommons.org/licenses/by/2.0/',
#   'id': 4,
#   'name': 'Attribution License'},
#  {'url': 'http://creativecommons.org/licenses/by-sa/2.0/',
#   'id': 5,
#   'name': 'Attribution-ShareAlike License'},
#  {'url': 'http://creativecommons.org/licenses/by-nd/2.0/',
#   'id': 6,
#   'name': 'Attribution-NoDerivs License'},
#  {'url': 'http://flickr.com/commons/usage/',
#   'id': 7,
#   'name': 'No known copyright restrictions'},
#  {'url': 'http://www.usa.gov/copyright.shtml',
#   'id': 8,
#   'name': 'United States Government Work'}]

# %%
val_annotations['images'].__len__()
# Out:
# 5000

# %% [markdown]
# #### explore train annotations

# %%
train_annotations.keys()
# Out:
# dict_keys(['info', 'licenses', 'images', 'annotations', 'categories'])

# %%
train_annotations['categories'][0:10]
# Out:
# [{'segmentation': [[267.03,
#     243.78,
#     314.59,
#     154.05,
#     357.84,
#     136.76,
#     374.05,
#     104.32,
#     410.81,
#     110.81,
#     429.19,
#     131.35,
#     420.54,
#     165.95,
#     451.89,
#     209.19,
#     464.86,
#     240.54,
#     480,
#     253.51,
#     484.32,
#     263.24,
#     496.22,
#     271.89,
#     484.32,
#     278.38,
#     438.92,
#     257.84,
#     401.08,
#     216.76,
#     370.81,
#     247.03,
#     414.05,
#     277.3,
#     433.51,
#     304.32,
#     443.24,
#     323.78,
#     400,
#     362.7,
#     376.22,
#     375.68,
#     400,
#     418.92,
#     394.59,
#     424.32,
#     337.3,
#     382.16,
#     337.3,
#     371.35,
#     388.11,
#     327.03,
#     341.62,
#     301.08,
#     311.35,
#     276.22,
#     304.86,
#     263.24,
#     294.05,
#     249.19]],
#   'num_keypoints': 8,
#   'area': 28292.08625,
#   'iscrowd': 0,
#   'keypoints': [0,
#    0,
#    0,
#    0,
#    0,
#    0,
#    0,
#    0,
#    0,
# ...

# %%
train_annotations['images'].__len__()
# Out:
# 118287

# %%
train_annotations['images'][0:10]
# Out:
# [{'license': 3,
#   'file_name': '000000391895.jpg',
#   'coco_url': 'http://images.cocodataset.org/train2017/000000391895.jpg',
#   'height': 360,
#   'width': 640,
#   'date_captured': '2013-11-14 11:18:45',
#   'flickr_url': 'http://farm9.staticflickr.com/8186/8119368305_4e622c8349_z.jpg',
#   'id': 391895},
#  {'license': 4,
#   'file_name': '000000522418.jpg',
#   'coco_url': 'http://images.cocodataset.org/train2017/000000522418.jpg',
#   'height': 480,
#   'width': 640,
#   'date_captured': '2013-11-14 11:38:44',
#   'flickr_url': 'http://farm1.staticflickr.com/1/127244861_ab0c0381e7_z.jpg',
#   'id': 522418},
#  {'license': 3,
#   'file_name': '000000184613.jpg',
#   'coco_url': 'http://images.cocodataset.org/train2017/000000184613.jpg',
#   'height': 336,
#   'width': 500,
#   'date_captured': '2013-11-14 12:36:29',
#   'flickr_url': 'http://farm3.staticflickr.com/2169/2118578392_1193aa04a0_z.jpg',
#   'id': 184613},
#  {'license': 3,
#   'file_name': '000000318219.jpg',
# ...
